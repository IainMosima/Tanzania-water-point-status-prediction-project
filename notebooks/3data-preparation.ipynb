# %%
# Importing necessary libraries
# Importing necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
pd.set_option('display.max_columns', None)

sns.set_style("whitegrid")
# %matplotlib inline

# setting font size for all plots
font = {'size'   : 16}

plt.rc('font', **font)

# %%
# importing the cleaned X_train dataset and y_train
X_train = pd.read_csv('../analysis-dfs/X_train_cleaned.csv')
X_train.drop('Unnamed: 0', axis=1, inplace=True)

y_train = pd.read_csv('../analysis-dfs/y_train.csv')
y_train.drop('Unnamed: 0', axis=1, inplace=True)

# importing the cleaned X_test dataset and y_test
X_test = pd.read_csv('../analysis-dfs/X_test_cleaned.csv')
y_test = pd.read_csv('../analysis-dfs/y_test.csv')

# %%
display(X_train.shape)
X_train.head(10)
# Out:
# (17807, 17)
#    gps_height   installer  longitude      latitude                    basin  \
# 0         340        finw  39.483463 -1.060527e+01  ruvuma / southern coast
# 1           0     unknown  34.081729 -8.789536e+00                   rufiji
# 2           0     unknown  34.294701 -8.701257e+00                   rufiji
# 3         123         dwe  37.851370 -7.197111e+00              wami / ruvu
# 4        1209         dwe  33.591998 -2.129478e+00            lake victoria
# 5        1170         dwe  32.908859 -1.936028e+00            lake victoria
# 6           0         dwe  31.474670 -1.471748e+00            lake victoria
# 7           0         dwe  34.803164 -2.000000e-08            lake victoria
# 8        1043  government  35.078078 -1.079965e+01  ruvuma / southern coast
# 9        2117       commu  33.933526 -8.957378e+00                   rufiji
#
#    region_code  district_code  population  permit construction_year  \
# 0            9              4       300.0    True              1982
# 1           12              7         1.0    True           unknown
# 2           12              7         1.0    True           unknown
# 3            5              2       250.0    True              1997
# 4           20              4       300.0   False              2008
# 5           19              1       500.0    True              1996
# 6           18              2         1.0    True           unknown
# 7           17              1         1.0   False           unknown
# 8           10              3        50.0    True              1990
# 9           11              3         1.0   False              1974
#
#   extraction_type_class management_group                payment quality_group  \
# 0           submersible       user-group              never pay          good
# 1               gravity       user-group            pay monthly          good
# 2               gravity       user-group              never pay          good
# 3                 other       user-group            pay monthly         salty
# 4                 other       user-group                unknown       unknown
# 5                 other       user-group              never pay          good
# 6              handpump       user-group              never pay          good
# 7              handpump       parastatal              never pay         salty
# 8               gravity       user-group                unknown          good
# 9               gravity       user-group  pay when scheme fails          good
#
#   quantity_group source_class waterpoint_type_group
# 0            dry  groundwater    communal standpipe
# 1   insufficient      surface    communal standpipe
# 2       seasonal      surface    communal standpipe
# 3   insufficient  groundwater                 other
# 4        unknown  groundwater                 other
# 5   insufficient  groundwater                 other
# 6   insufficient  groundwater             hand pump
# 7         enough  groundwater             hand pump
# 8            dry  groundwater    communal standpipe
# 9         enough  groundwater    communal standpipe

# %% [markdown]
# # Data Scaling

# %% [markdown]
# All of the features of numerical data type are in a different scale this will hinder the training process of a model.

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17807 entries, 0 to 17806
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   gps_height             17807 non-null  int64
#  1   installer              17807 non-null  object
#  2   longitude              17807 non-null  float64
#  3   latitude               17807 non-null  float64
#  4   basin                  17807 non-null  object
#  5   region_code            17807 non-null  int64
#  6   district_code          17807 non-null  int64
#  7   population             17807 non-null  float64
#  8   permit                 17807 non-null  bool
#  9   construction_year      17807 non-null  object
#  10  extraction_type_class  17807 non-null  object
#  11  management_group       17807 non-null  object
#  12  payment                17807 non-null  object
#  13  quality_group          17807 non-null  object
#  14  quantity_group         17807 non-null  object
#  15  source_class           17807 non-null  object
#  16  waterpoint_type_group  17807 non-null  object
# dtypes: bool(1), float64(3), int64(3), object(10)
# memory usage: 2.2+ MB

# %%
numerics = ['int64', 'float64'] # list of all numerical dtypes
numericals = X_train.select_dtypes(include=numerics)

# selecting non-numerical dtypes.
not_numericals = X_train.select_dtypes(exclude=numerics)

# %%
# Using standardscaler I will set all numerical values to be on the same scale.
sc = StandardScaler()
numericals_scaled = sc.fit_transform(numericals)

numericals_scaled_df = pd.DataFrame(numericals_scaled, columns=numericals.columns, index=numericals.index)

# dropping the numerical columns and then adding the new scaled columns
X_train_scaled = pd.concat([not_numericals, numericals_scaled_df], axis = 1)
X_train_scaled
# Out:
#                            installer                    basin  permit  \
# 0                               finw  ruvuma / southern coast    True
# 1                            unknown                   rufiji    True
# 2                            unknown                   rufiji    True
# 3                                dwe              wami / ruvu    True
# 4                                dwe            lake victoria   False
# ...                              ...                      ...     ...
# 17802     sengerema water department            lake victoria    True
# 17803  halmashauri ya wilaya sikonge          lake tanganyika    True
# 17804                         villag            lake victoria    True
# 17805                      rc church                 internal    True
# 17806                            dwe                 internal   False
#
#       construction_year extraction_type_class management_group  \
# 0                  1982           submersible       user-group
# 1               unknown               gravity       user-group
# 2               unknown               gravity       user-group
# 3                  1997                 other       user-group
# 4                  2008                 other       user-group
# ...                 ...                   ...              ...
# 17802           unknown              handpump       user-group
# 17803           unknown                 other       user-group
# 17804           unknown                 other       user-group
# 17805           unknown               gravity       parastatal
# 17806           unknown           submersible       user-group
#
#               payment quality_group quantity_group source_class  \
# 0           never pay          good            dry  groundwater
# 1         pay monthly          good   insufficient      surface
# 2           never pay          good       seasonal      surface
# 3         pay monthly         salty   insufficient  groundwater
# 4             unknown       unknown        unknown  groundwater
# ...               ...           ...            ...          ...
# 17802       never pay          good            dry  groundwater
# 17803       never pay          good            dry  groundwater
# 17804           other         milky   insufficient  groundwater
# 17805         unknown          good   insufficient      surface
# 17806  pay per bucket         salty         enough  groundwater
#
#       waterpoint_type_group  gps_height  longitude  latitude  region_code  \
# 0        communal standpipe   -0.356274   1.723728 -1.640197    -0.393261
# 1        communal standpipe   -0.884573  -0.348901 -1.036569    -0.240379
# 2        communal standpipe   -0.884573  -0.267184 -1.007222    -0.240379
# 3                     other   -0.693453   1.097498 -0.507180    -0.597103
# 4                     other    0.993994  -0.536809  1.177516     0.167305
# ...                     ...         ...        ...       ...          ...
# 17802             hand pump   -0.884573  -0.834161  1.045397     0.116345
# 17803                 other   -0.884573  -0.843981 -0.039702    -0.138458
# 17804                 other   -0.884573  -0.692996  0.906643     0.116345
# 17805    communal standpipe   -0.884573  -0.335219  0.615404     0.014424
# 17806                 other   -0.884573  -0.584783  0.640126     0.014424
#
#        district_code  population
# 0          -0.194167    1.366671
# 1           0.092932   -0.675954
# 2           0.092932   -0.675954
# 3          -0.385566    1.025095
# 4          -0.194167    1.366671
# ...              ...         ...
# 17802      -0.098467   -0.675954
# 17803      -0.098467   -0.675954
# 17804       0.092932   -0.675954
# 17805       0.188631   -0.675954
# 17806       0.092932   -0.675954
#
# [17807 rows x 17 columns]

# %% [markdown]
# # Data Conversion

# %% [markdown]
# #### The permit column
# The permit column contains boolean information which can also be interpreted in a binary format.

# %%
# Checking values before encoding
X_train_scaled.permit.value_counts()
# Out:
# True     12374
# False     5433
# Name: permit, dtype: int64

# %%
# Using label encoder to transform the permit column
le = LabelEncoder()
le.fit(X_train_scaled.permit)
X_train_scaled.permit = le.transform(X_train_scaled.permit)
X_train_scaled.permit.value_counts()
# Out:
# 1    12374
# 0     5433
# Name: permit, dtype: int64

# %%
#  reviweing the new dataset
X_train_scaled.head(10)
# Out:
#     installer                    basin  permit construction_year  \
# 0        finw  ruvuma / southern coast       1              1982
# 1     unknown                   rufiji       1           unknown
# 2     unknown                   rufiji       1           unknown
# 3         dwe              wami / ruvu       1              1997
# 4         dwe            lake victoria       0              2008
# 5         dwe            lake victoria       1              1996
# 6         dwe            lake victoria       1           unknown
# 7         dwe            lake victoria       0           unknown
# 8  government  ruvuma / southern coast       1              1990
# 9       commu                   rufiji       0              1974
#
#   extraction_type_class management_group                payment quality_group  \
# 0           submersible       user-group              never pay          good
# 1               gravity       user-group            pay monthly          good
# 2               gravity       user-group              never pay          good
# 3                 other       user-group            pay monthly         salty
# 4                 other       user-group                unknown       unknown
# 5                 other       user-group              never pay          good
# 6              handpump       user-group              never pay          good
# 7              handpump       parastatal              never pay         salty
# 8               gravity       user-group                unknown          good
# 9               gravity       user-group  pay when scheme fails          good
#
#   quantity_group source_class waterpoint_type_group  gps_height  longitude  \
# 0            dry  groundwater    communal standpipe   -0.356274   1.723728
# 1   insufficient      surface    communal standpipe   -0.884573  -0.348901
# 2       seasonal      surface    communal standpipe   -0.884573  -0.267184
# 3   insufficient  groundwater                 other   -0.693453   1.097498
# 4        unknown  groundwater                 other    0.993994  -0.536809
# 5   insufficient  groundwater                 other    0.933395  -0.798928
# 6   insufficient  groundwater             hand pump   -0.884573  -1.349221
# 7         enough  groundwater             hand pump   -0.884573  -0.072088
# 8            dry  groundwater    communal standpipe    0.736060   0.033395
# 9         enough  groundwater    communal standpipe    2.404861  -0.405766
#
#    latitude  region_code  district_code  population
# 0 -1.640197    -0.393261      -0.194167    1.366671
# 1 -1.036569    -0.240379       0.092932   -0.675954
# 2 -1.007222    -0.240379       0.092932   -0.675954
# 3 -0.507180    -0.597103      -0.385566    1.025095
# 4  1.177516     0.167305      -0.194167    1.366671
# 5  1.241827     0.116345      -0.481266    2.732976
# 6  1.396173     0.065384      -0.385566   -0.675954
# 7  1.885445     0.014424      -0.481266   -0.675954
# 8 -1.704817    -0.342300      -0.289867   -0.341209
# 9 -1.092367    -0.291340      -0.289867   -0.675954
