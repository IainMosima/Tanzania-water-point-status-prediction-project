# %%
# Importing necessary libraries
import pandas as pd
from myfunctions import set_importer, scores, data_preparation, data_cleaner
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import plot_confusion_matrix, train_test_split
from sklearn.ensemble import RandomForestClassifier

sns.set_style("whitegrid")
# %matplotlib inline

# setting font size for all plots
font = {'size'   : 16}

plt.rc('font', **font)

# %% [markdown]
# # The best Model

# %% [markdown]
# After experimenting with various models, a random forest classifier was found to be the ideal model

# %%
class myRandomForestClassifier:
    def __init__(self):
        self.rf_classifier =  RandomForestClassifier(criterion='gini', random_state=21, min_samples_split=70, min_samples_leaf=100, n_estimators=300)
    
    def Xy_cleanprep(self, X, y):
        #1. data cleaning
        X_cleaned, y_cleaned = data_cleaner(X, y)

        # 2. data preparation
        X_ordinal_encoded, X_onehotencoded, y_prepared = data_preparation(X_cleaned, y_cleaned)

        columns_to_select = ['gps_height','longitude','latitude','region_code','district_code',
        'population','permit','construction_year','basin','extraction_type_class','payment','quality_group','quantity_group','source_class','waterpoint_type_group']

        return X_ordinal_encoded[columns_to_select], y_prepared
        
    
    def fit(self, X, y):
        
        X_ready, y_ready = self.Xy_cleanprep(X, y)

        return self.rf_classifier.fit(X_ready, y_ready)
    
    def predict(self, X_true):
        columns_to_select = ['gps_height','longitude','latitude','region_code','district_code',
        'population','permit','construction_year','basin','extraction_type_class','payment','quality_group','quantity_group','source_class','waterpoint_type_group']
        return self.rf_classifier.predict(X_true[columns_to_select])

# %%
# importing the data frame
df = set_importer('../analysis-dfs/df.csv')
df.head(10)
# Out:
#       id  amount_tsh date_recorded                  funder  gps_height  \
# 0  67743         0.0    2013-01-28                  Unicef         263
# 1  19816         0.0    2012-10-01                    Dwsp           0
# 2  54551         0.0    2012-10-09                   Rwssp           0
# 3  53934         0.0    2012-11-03                Wateraid           0
# 4  48451       500.0    2011-07-04                  Unicef        1703
# 5  58155         0.0    2011-09-04                  Unicef        1656
# 6  34169         0.0    2011-07-22                  Hesawa        1162
# 7  58500         0.0    2011-10-04                  Unicef        1510
# 8  22308         0.0    2013-02-25  Government Of Tanzania        1273
# 9  19685         0.0    2013-03-05  Government Of Tanzania        1443
#
#           installer  longitude   latitude              wpt_name  num_private  \
# 0            UNICEF  38.486161 -11.155298  Zahanati Ya Nanyumbu            0
# 1              DWSP  33.362410  -3.766365            Kwa Ngomho            0
# 2               DWE  32.620617  -4.226198          Tushirikiane            0
# 3         Water Aid  32.711100  -5.146712     Kwa Ramadhan Musa            0
# 4               DWE  34.642439  -9.106185       Kwa John Mtenzi            0
# 5               DWE  34.569266  -9.085515       Kwa Rose Chaula            0
# 6               DWE  32.920154  -1.947868                Ngomee            0
# 7               DWE  34.586901  -8.980014               Shuleni            0
# 8               DWE  37.422751  -3.317536             Kwa Tukai            0
# 9  District council  37.611126  -3.263526          Kwa Kibakaya            0
#
#                      basin       subvillage       region  region_code  \
# 0  Ruvuma / Southern Coast       Mahakamani       Mtwara           90
# 1                 Internal    Ishinabulandi    Shinyanga           17
# 2          Lake Tanganyika  Nyawishi Center    Shinyanga           17
# 3          Lake Tanganyika       Imalauduki       Tabora           14
# 4                   Rufiji         Kidudumo       Iringa           11
# 5                   Rufiji           Yeriko       Iringa           11
# 6            Lake Victoria           Center       Mwanza           19
# 7                   Rufiji        Mkanivega       Iringa           11
# 8                  Pangani         Kitereni  Kilimanjaro            3
# 9                  Pangani            Kiyao  Kilimanjaro            3
#
#    district_code              lga          ward  population public_meeting  \
# 0             63         Nanyumbu      Nanyumbu          58           True
# 1              3  Shinyanga Rural        Samuye           0           True
# 2              3           Kahama        Chambo           0           True
# 3              6     Tabora Urban      Itetemia           0           True
# 4              4           Njombe        Mdandu          35           True
# 5              4           Njombe         Usuka          50           True
# 6              1          Ukerewe      Ilangala        1000            NaN
# 7              4           Njombe         Usuka         350           True
# 8              4      Moshi Rural       Kimochi         140           True
# 9              1            Rombo  Mengwe Manda           1           True
#
#                recorded_by scheme_management                  scheme_name  \
# 0  GeoData Consultants Ltd               VWC                          NaN
# 1  GeoData Consultants Ltd               VWC                          NaN
# 2  GeoData Consultants Ltd               NaN                          NaN
# 3  GeoData Consultants Ltd               VWC                          NaN
# 4  GeoData Consultants Ltd               WUA  wanging'ombe water supply s
# 5  GeoData Consultants Ltd               WUA  wanging'ombe water supply s
# 6  GeoData Consultants Ltd               NaN                          NaN
# 7  GeoData Consultants Ltd               WUA  wanging'ombe water supply s
# 8  GeoData Consultants Ltd               VWC               Komaka mandaka
# 9  GeoData Consultants Ltd           Company        Kitukuni water supply
#
#   permit  construction_year extraction_type extraction_type_group  \
# 0   True               1986     submersible           submersible
# 1   True                  0          swn 80                swn 80
# 2   True                  0     nira/tanira           nira/tanira
# 3   True                  0   india mark ii         india mark ii
# 4   True               1978         gravity               gravity
# 5   True               1978         gravity               gravity
# 6   True               1999           other                 other
# 7   True               1978         gravity               gravity
# 8   True               1974         gravity               gravity
# 9   True               2000         gravity               gravity
#
#   extraction_type_class management management_group                payment  \
# 0           submersible        vwc       user-group              never pay
# 1              handpump        vwc       user-group              never pay
# 2              handpump        wug       user-group                unknown
# 3              handpump        vwc       user-group              never pay
# 4               gravity        wua       user-group            pay monthly
# 5               gravity        wua       user-group  pay when scheme fails
# 6                 other        vwc       user-group              never pay
# 7               gravity        wua       user-group              never pay
# 8               gravity        vwc       user-group                unknown
# 9               gravity    company       commercial            pay monthly
#
#   payment_type water_quality quality_group      quantity quantity_group  \
# 0    never pay          soft          good           dry            dry
# 1    never pay          soft          good        enough         enough
# 2      unknown         milky         milky        enough         enough
# 3    never pay         salty         salty      seasonal       seasonal
# 4      monthly          soft          good           dry            dry
# 5   on failure          soft          good           dry            dry
# 6    never pay         milky         milky  insufficient   insufficient
# 7    never pay          soft          good        enough         enough
# 8      unknown          soft          good        enough         enough
# 9      monthly          soft          good  insufficient   insufficient
#
#          source   source_type source_class              waterpoint_type  \
# 0   machine dbh      borehole  groundwater  communal standpipe multiple
# 1   machine dbh      borehole  groundwater                    hand pump
# 2  shallow well  shallow well  groundwater                    hand pump
# 3   machine dbh      borehole  groundwater                    hand pump
# 4         river    river/lake      surface           communal standpipe
# 5         river    river/lake      surface           communal standpipe
# 6        spring        spring  groundwater                        other
# 7         river    river/lake      surface           communal standpipe
# 8        spring        spring  groundwater           communal standpipe
# 9        spring        spring  groundwater           communal standpipe
#
#   waterpoint_type_group             status_group
# 0    communal standpipe           non functional
# 1             hand pump           non functional
# 2             hand pump           non functional
# 3             hand pump           non functional
# 4    communal standpipe           non functional
# 5    communal standpipe           non functional
# 6                 other  functional needs repair
# 7    communal standpipe  functional needs repair
# 8    communal standpipe  functional needs repair
# 9    communal standpipe           non functional

# %%
X = df.drop('status_group', axis=1)
y = df.status_group
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.30, random_state=21)

# %%
clf = myRandomForestClassifier()
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(min_samples_leaf=100, min_samples_split=70,
#                        n_estimators=300, random_state=21)

# %%
# passing  the test set to a cleaner
X_test_ready, y_test_ready = clf.Xy_cleanprep(X_test, y_test)

# %%
y_test_rf_preds = clf.predict(X_test_ready)
# print('RandomForest Classifier best model results on the training set')
scores(y_test_ready, y_test_rf_preds)
# Out:
# The precision score is:	 0.8478688524590164
# The recall score is:	 0.9998453448809156
# The accuracy score is:	 0.8477576711250984
# The f1 score is:	 0.9176069831807537

# %% [markdown]
# ## Interpretating the final model

# %% [markdown]
# * Precision-Score - If the model assigns 1 then there is a 85% chance that a water pump is actually non functional.
# * Recal-Score - If a given water pump is actually 1 (non-functional) then there is a 99.9% that this model will label it as 1 (non-functional), and a 0.1% chance that it will incorrectly label it as 0 (functional but need repair).
# * Accuracy-Score - The model accrately assigns 84.8% to the correct label. (0.8375295043273013)
